// %% [markdown]
// # ScaFi on jupyter notebook
// A PoF for ScaFi script running on a notebook. It should be useful for learning purpose

// %% [markdown]
// ## ScaFi dependecy

// %%
import $ivy.`io.github.cric96::scalapy-gym:0.1.0`
// Out:
// Downloading https://repo1.maven.org/maven2/io/github/cric96/scalapy-gym_2.13/0.1.0/scalapy-gym_2.13-0.1.0.pom
// Downloaded https://repo1.maven.org/maven2/io/github/cric96/scalapy-gym_2.13/0.1.0/scalapy-gym_2.13-0.1.0.pom
// Downloading https://repo1.maven.org/maven2/me/shadaj/scalapy-core_2.13/0.5.0/scalapy-core_2.13-0.5.0.pom
// Downloaded https://repo1.maven.org/maven2/me/shadaj/scalapy-core_2.13/0.5.0/scalapy-core_2.13-0.5.0.pom
// Downloading https://repo1.maven.org/maven2/me/shadaj/scalapy-macros_2.13/0.5.0/scalapy-macros_2.13-0.5.0.pom
// Downloaded https://repo1.maven.org/maven2/me/shadaj/scalapy-macros_2.13/0.5.0/scalapy-macros_2.13-0.5.0.pom
// Downloading https://repo1.maven.org/maven2/me/shadaj/scalapy-core_2.13/0.5.0/scalapy-core_2.13-0.5.0.jar
// Downloading https://repo1.maven.org/maven2/me/shadaj/scalapy-macros_2.13/0.5.0/scalapy-macros_2.13-0.5.0-sources.jar
// Downloading https://repo1.maven.org/maven2/me/shadaj/scalapy-macros_2.13/0.5.0/scalapy-macros_2.13-0.5.0.jar
// Downloading https://repo1.maven.org/maven2/io/github/cric96/scalapy-gym_2.13/0.1.0/scalapy-gym_2.13-0.1.0-sources.jar
// Downloading https://repo1.maven.org/maven2/me/shadaj/scalapy-core_2.13/0.5.0/scalapy-core_2.13-0.5.0-sources.jar
// Downloading https://repo1.maven.org/maven2/io/github/cric96/scalapy-gym_2.13/0.1.0/scalapy-gym_2.13-0.1.0.jar
// Downloaded https://repo1.maven.org/maven2/me/shadaj/scalapy-core_2.13/0.5.0/scalapy-core_2.13-0.5.0.jar
// Downloaded https://repo1.maven.org/maven2/me/shadaj/scalapy-core_2.13/0.5.0/scalapy-core_2.13-0.5.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/me/shadaj/scalapy-macros_2.13/0.5.0/scalapy-macros_2.13-0.5.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/me/shadaj/scalapy-macros_2.13/0.5.0/scalapy-macros_2.13-0.5.0.jar
// Downloaded https://repo1.maven.org/maven2/io/github/cric96/scalapy-gym_2.13/0.1.0/scalapy-gym_2.13-0.1.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/github/cric96/scalapy-gym_2.13/0.1.0/scalapy-gym_2.13-0.1.0.jar
// import $ivy.$

// %% [markdown]
// ## Incarnation definition

// %%
import io.github.cric96.gym.envs.EnvFactory.ToyText
// Out:
// import io.github.cric96.gym.envs.EnvFactory.ToyText

// %% [markdown]
// ## Simulator definition

// %%
val env = ToyText.frozenLakeV1()
env.actionSpace
// Out:
// me.shadaj.scalapy.py.PythonException: <class 'ModuleNotFoundError'> No module named 'scipy'
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.$anonfun$throwErrorIfOccured$2(CPythonInterpreter.scala:316)
//   me.shadaj.scalapy.interpreter.Platform$.Zone(Platform.scala:10)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.$anonfun$throwErrorIfOccured$1(CPythonInterpreter.scala:302)
//   scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.withGil(CPythonInterpreter.scala:148)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.throwErrorIfOccured(CPythonInterpreter.scala:301)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.$anonfun$runCallableAndDecref$1(CPythonInterpreter.scala:424)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.withGil(CPythonInterpreter.scala:148)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.runCallableAndDecref(CPythonInterpreter.scala:408)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.$anonfun$call$2(CPythonInterpreter.scala:459)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.withGil(CPythonInterpreter.scala:148)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.$anonfun$call$1(CPythonInterpreter.scala:455)
//   me.shadaj.scalapy.interpreter.Platform$.Zone(Platform.scala:10)
//   me.shadaj.scalapy.interpreter.CPythonInterpreter$.call(CPythonInterpreter.scala:454)
//   me.shadaj.scalapy.py.AnyDynamics.applyDynamic(Dynamic.scala:38)
//   me.shadaj.scalapy.py.AnyDynamics.applyDynamic$(Dynamic.scala:36)
//   io.github.cric96.gym.Gym$$anon$1$$anon$2.applyDynamic(Gym.scala:19)
//   io.github.cric96.gym.Gym$.make(Gym.scala:19)
//   io.github.cric96.gym.envs.EnvFactory$ToyText$.frozenLakeV1(EnvFactory.scala:15)
//   ammonite.$sess.cmd2$Helper.<init>(cmd2.sc:1)
//   ammonite.$sess.cmd2$.<clinit>(cmd2.sc:7)

// %% [markdown]
// ## Program definition

// %%
val program = new AggregateProgram {
  override def main(): Any = rep(0)(_ + 1)
}
// Out:
// program: AnyRef with AggregateProgram = <function1>

// %% [markdown]
// ## Program execution

// %%
simulation.exec(program)
// Out:
// res5: (ID, EXPORT) = (98, Map(P:/Rep(0) -> 1, P:/ -> 1))
